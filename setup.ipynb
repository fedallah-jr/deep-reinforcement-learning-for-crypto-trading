# %%
# !git clone https://github.com/fedallah-jr/deep-reinforcement-learning-for-crypto-trading.git
# Out:
# Cloning into 'deep-reinforcement-learning-for-crypto-trading'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 83 (delta 26), reused 60 (delta 12), pack-reused 0 (from 0)
# Unpacking objects: 100% (83/83), done.

# %%
# %cd deep-reinforcement-learning-for-crypto-trading
# Out:
# /deep-reinforcement-learning-for-crypto-trading

# %%
# !conda install -c conda-forge gcc -y
# Out:
# ...
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 24.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gcc
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     binutils_impl_linux-64-2.43|       h4bf12b8_1         5.9 MB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     conda-4.14.0               |   py37h89c1867_0        1010 KB  conda-forge
#     gcc-14.1.0                 |       h6f9ffa1_1          53 KB  conda-forge
#     gcc_impl_linux-64-14.1.0   |       h3c94d91_1        69.7 MB  conda-forge
# ...

# %%
# !conda remove --name sane_ai_4 --all -y

# !conda env create -f environment.yml
# Out:
# Remove all packages in environment /opt/conda/envs/sane_ai_4:
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/sane_ai_4
#
#
# The following packages will be REMOVED:
#
#   _libgcc_mutex-0.1-conda_forge
#   _openmp_mutex-4.5-2_gnu
#   anyio-3.6.2-pyhd8ed1ab_0
#   argon2-cffi-21.3.0-pyhd8ed1ab_0
#   argon2-cffi-bindings-21.2.0-py39hb9d737c_3
#   asttokens-2.2.1-pyhd8ed1ab_0
#   attrs-22.2.0-pyh71513ae_0
#   babel-2.11.0-pyhd8ed1ab_0
#   backcall-0.2.0-pyh9f0ad1d_0
#   backports-1.0-pyhd8ed1ab_3
#   backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0
#   beautifulsoup4-4.11.1-pyha770c72_0
#   bleach-6.0.0-pyhd8ed1ab_0
#   brotlipy-0.7.0-py39hb9d737c_1005
#   ca-certificates-2022.12.7-ha878542_0
#   certifi-2022.12.7-pyhd8ed1ab_0
#   cffi-1.14.6-py39he32792d_0
#   charset-normalizer-2.1.1-pyhd8ed1ab_0
#   comm-0.1.2-pyhd8ed1ab_0
#   cryptography-39.0.0-py39hd598818_0
#   cudatoolkit-11.2.2-hbe64b41_11
#   debugpy-1.6.6-py39h227be39_0
#   decorator-5.1.1-pyhd8ed1ab_0
# ...

# %%
# !python -m ipykernel install --user --name=sane_ai_4
# Out:
# Installed kernelspec sane_ai_4 in /root/.local/share/jupyter/kernels/sane_ai_4

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_339/630927516.py in <module>
# ----> 1 import san
#
# ModuleNotFoundError: No module named 'san'
